# %%
# Install the radon package if you haven't already
# pip install radon

from radon.metrics import mi_visit
from radon.complexity import cc_visit

# Example: Read your model's code file
with open('RandomForest.py', 'r') as file:
    code = file.read()

# Calculate the Maintainability Index
mi_score = mi_visit(code, True)  # True gives the score on a 0-100 scale

print(f"Maintainability Index Score: {mi_score}")
# Out:
# Maintainability Index Score: 65.2545274377009

# %%
# Install the radon package if you haven't already
# pip install radon

from radon.metrics import mi_visit
from radon.complexity import cc_visit

# Example: Read your model's code file
with open('CatBoost.py', 'r') as file:
    code = file.read()

# Calculate the Maintainability Index
mi_score = mi_visit(code, True)  # True gives the score on a 0-100 scale

print(f"Maintainability Index Score: {mi_score}")
# Out:
# Maintainability Index Score: 77.1398027281854

# %%
# Install the radon package if you haven't already
# pip install radon

from radon.metrics import mi_visit
from radon.complexity import cc_visit

# Example: Read your model's code file
with open('XGBoost.py', 'r') as file:
    code = file.read()

# Calculate the Maintainability Index
mi_score = mi_visit(code, True)  # True gives the score on a 0-100 scale

print(f"Maintainability Index Score: {mi_score}")
# Out:
# Maintainability Index Score: 76.01379202592814

# %%
# Install the radon package if you haven't already
# pip install radon

from radon.metrics import mi_visit
from radon.complexity import cc_visit

# Example: Read your model's code file
with open('LightGBM.py', 'r') as file:
    code = file.read()
    
# Calculate the Maintainability Index
mi_score = mi_visit(code, True)  # True gives the score on a 0-100 scale

print(f"Maintainability Index Score: {mi_score}")
# Out:
# Maintainability Index Score: 74.17998502167178
